# %%
import pandas as pd
import numpy as np

nf=pd.read_csv("etflix Dataset Latest 2021.csv")

nf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9266 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %%
nf=nf.dropna(subset=["IMDB_ID"])
nf
# Out:
#                        Title                                   Genre  \
# 0           Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1        HOW TO BUILD A GIRL                                  Comedy
# 2           The Con-Heartist                         Comedy, Romance
# 3               Gleboka woda                                   Drama
# 4              Only a Mother                                   Drama
# ...                      ...                                     ...
# 9417                 4.3.2.1                         Crime, Thriller
# 9418                      13                  Crime, Drama, Thriller
# 9419  District 13: Ultimatum                 Action, Crime, Thriller
# 9420          13 Going on 30                Comedy, Fantasy, Romance
# 9421                LIFE 2.0                             Documentary
#
#                                                    Tags            Languages  \
# ...

# %%
tmdb=pd.read_csv("TMDB Website Movie Database.csv")
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159725 entries, 0 to 159724
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 159725 non-null  int64
#  1   FILMID             159725 non-null  int64
#  2   TITLE              159725 non-null  object
#  3   ADULT              159725 non-null  bool
#  4   BACKDROP_PATH      58724 non-null   object
#  5   BUDGET             159725 non-null  int64
#  6   HOMEPAGE           15848 non-null   object
#  7   IMDB_ID            149399 non-null  object
#  8   ORIGINAL_LANGUAGE  159725 non-null  object
#  9   ORIGINAL_TITLE     159725 non-null  object
#  10  OVERVIEW           135783 non-null  object
#  11  POPULARITY         159725 non-null  float64
#  12  POSTER_PATH        115972 non-null  object
#  13  RELEASE_DATE       159725 non-null  object
#  14  REVENUE            159725 non-null  int64
# ...

# %%
tmdb=tmdb.dropna(subset=["IMDB_ID"])
tmdb
# Out:
#             ID  FILMID                          TITLE  ADULT  \
# 0            1  741067        Welcome to Sudden Death  False
# 1            2  497582                   Enola Holmes  False
# 2            3  749544             Brutal Bridesmaids  False
# 3            4  669666                           Home  False
# 4            5  528085                           2067  False
# ...        ...     ...                            ...    ...
# 159718  167595   74178                Little Hercules  False
# 159720  167597  741828  Mutterliebe - Der Usedomkrimi  False
# 159722  167599   74181                   Stuborn Fate  False
# 159723  167600   74183                   Land of Love  False
# 159724  167601   74184       The Legend of Hallowdega  False
#
#                            BACKDROP_PATH    BUDGET  \
# 0       /aO5ILS7qnqtFIprbJ40zla0jhpu.jpg         0
# 1       /kMe4TKMDNXTKptQPAdOF0oZHq3V.jpg  21000000
# 2                                    NaN         0
# ...

# %%
match=pd.merge(nf, tmdb, on=["IMDB_ID"], how="right")

match
# Out:
#                Title                                     Genre  \
# 0                NaN                                       NaN
# 1       Enola Holmes  Action, Adventure, Crime, Drama, Mystery
# 2                NaN                                       NaN
# 3                NaN                                       NaN
# 4                NaN                                       NaN
# ...              ...                                       ...
# 149573           NaN                                       NaN
# 149574           NaN                                       NaN
# 149575           NaN                                       NaN
# 149576           NaN                                       NaN
# 149577           NaN                                       NaN
#
#                                                      Tags Languages  \
# 0                                                     NaN       NaN
# 1       Children & Family Movies,Action & Adventure,Dr...   English
# ...

# %%
m=match.dropna(subset=["Title"])
m
# Out:
#                            Title                                     Genre  \
# 1                   Enola Holmes  Action, Adventure, Crime, Drama, Mystery
# 10                           Ava            Action, Crime, Drama, Thriller
# 12               Hubie Halloween                  Comedy, Fantasy, Mystery
# 24                 Project Power           Action, Crime, Sci-Fi, Thriller
# 28             After We Collided                            Drama, Romance
# ...                          ...                                       ...
# 149416              Simon Killer                           Drama, Thriller
# 149473  The Day I Saw Your Heart                             Comedy, Drama
# 149496                 Carandiru                              Drama, Crime
# 149525                7 Days Out                               Documentary
# 149560        Ek Main Aur Ekk Tu                    Comedy, Drama, Romance
#
#                                                      Tags  \
# ...

# %%
m.to_csv(r'whole data.csv',index=False)
